# %%
import pandas as pd
import numpy as np

# %%
sample = pd.read_csv(r"raw-asset-data.csv")

# %%
sample.head()
# Out:
#                               Company Asset Name  Asset Tag  \
# 0  CapeStart Software Private Limited  CS-LP-304  CS-LP-304
# 1  CapeStart Software Private Limited  CS-LP-305  CS-LP-305
# 2  CapeStart Software Private Limited  CS-LP-306  CS-LP-306
# 3  CapeStart Software Private Limited  CS-LP-307  CS-LP-307
# 4  CapeStart Software Private Limited  CS-LP-308  CS-LP-308
#
#                        Model Model No. Category Manufacturer   Serial  \
# 0  Dell Latitude 3000 Series      3490   Laptop         Dell  3BWFBV2
# 1  Dell Latitude 3000 Series      3490   Laptop         Dell  B00HBV2
# 2  Dell Latitude 3000 Series      3490   Laptop         Dell  210HBV2
# 3  Dell Latitude 3000 Series      3490   Laptop         Dell  GYZGBV2
# 4  Dell Latitude 3000 Series      3490   Laptop         Dell  9BWFBV2
#
#         Purchased       Cost  ...  SPL Impedance Termination Webcam Interface  \
# 0  3/20/2019 0:00  74,222.00  ...  NaN       NaN         NaN    NaN       NaN
# ...

# %%
sample.columns
# Out:
# Index(['Company', 'Asset Name', 'Asset Tag', 'Model', 'Model No.', 'Category',
#        'Manufacturer', 'Serial', 'Purchased', 'Cost', 'EOL', 'Order Number',
#        'Supplier', 'Location', 'Address', 'Address.1', 'City', 'State',
#        'Country', 'Zip', 'Default Location', 'Address.2', 'Address.3',
#        'City.1', 'State.1', 'Country.1', 'Zip.1', 'Checked Out', 'Type',
#        'Username', 'Employee No.', 'Manager', 'Department', 'Status',
#        'Warranty', 'Warranty Expires', 'Value', 'Diff', 'Fully Depreciated',
#        'Checkout Date', 'Expected Checkin Date', 'Created at', 'Updated at',
#        'Last Audit', 'Next Audit Date', 'Notes', 'Memory Size', 'Display Size',
#        'Resolution', 'Panel Type', 'CPU', 'Generation', 'Core Count',
#        'Memory Type', 'Storage', 'Storage Type', 'Operating System',
#        'Endpoint Status', 'Domain Status', 'Storage Size', 'SoC',
#        'Contrast Ratio', 'Color Depth', 'Colors', 'Brightness',
# ...

# %%
pd.pivot_table?
# Out:
# Signature:
# pd.pivot_table(
#     data: 'DataFrame',
#     values=None,
#     index=None,
#     columns=None,
#     aggfunc: 'AggFuncType' = 'mean',
#     fill_value=None,
#     margins: 'bool' = False,
#     dropna: 'bool' = True,
#     margins_name: 'str' = 'All',
#     observed: 'bool' = False,
#     sort: 'bool' = True,
# ) -> 'DataFrame'
# Docstring:
# Create a spreadsheet-style pivot table as a DataFrame.
#
# The levels in the pivot table will be stored in MultiIndex objects
# (hierarchical indexes) on the index and columns of the result DataFrame.
#
# Parameters
# ----------
# data : DataFrame
# values : column to aggregate, optional
# index : column, Grouper, array, or list of the previous
#     If an array is passed, it must be the same length as the data. The
#     list can contain any of the other types (except list).
#     Keys to group by on the pivot table index.  If an array is passed,
#     it is being used as the same manner as column values.
# ...

# %%
from itertools import count
from operator import countOf


pd.pivot_table(sample, index=['CPU'], columns=['Status'], values=['Asset Tag'], aggfunc= np.count_nonzero, fill_value= 0, margins= True, margins_name="Total")
# Out:
#                                             Asset Tag                 \
# Status                  Awaiting Re-Imaging (pending) CSR (archived)
# CPU
# Apple M1                                            0              0
# Apple M2                                            0              0
# Intel Core 2 Duo                                    0              0
# Intel Core i3                                       0             23
# Intel Core i5                                       3             12
# Intel Core i7                                       0              1
# Intel Pentium Dual-Core                             0              0
# Intel Xeon                                          0              0
# Total                                               3             36
#
#                                                                         \
# Status                  CSR (deployed) New (deployable) OGF (archived)
# CPU
# ...

# %%
table=pd.pivot_table(sample, index=['CPU'], columns=['Status'], values=['Asset Tag'], aggfunc= np.count_nonzero, fill_value= 0, margins= True, margins_name="Total")

# %%
type(table)
# Out:
# pandas.core.frame.DataFrame

# %%
table.query('CPU== ["Intel Core i3", "Intel Core i5", "Intel Core i7", "Total"]')
# Out:
#                                   Asset Tag                                \
# Status        Awaiting Re-Imaging (pending) CSR (archived) CSR (deployed)
# CPU
# Intel Core i3                             0             23              2
# Intel Core i5                             3             12              0
# Intel Core i7                             0              1              0
# Total                                     3             36              2
#
#                                                                        \
# Status        New (deployable) OGF (archived) Production (deployable)
# CPU
# Intel Core i3                0              1                       0
# Intel Core i5               14              7                       2
# Intel Core i7                1              0                       0
# Total                       16              8                       2
#
#                                                                    \
# ...
